# %%
# %matplotlib inline
from Sonnet_HMM import *
import numpy as np
import matplotlib.pyplot as plt
import os
from IPython.display import HTML
from HMM_helper import (
    text_to_wordcloud,
    states_to_wordclouds,
    parse_observations,
    sample_sentence,
    visualize_sparsities,
    animate_emission
)

# %% [markdown]
# ## Visualization of the dataset

# %%
text = open(os.path.join(os.getcwd(), 'data/shakespeare.txt')).read()
wordcloud = text_to_wordcloud(text, title='Shakespearean Sonnets')

# %% [markdown]
# ## Training an HMM

# %%
hmm = Sonnet_HMM(N_state=12, train=False)
hmm.load_model("data/hmm_100")
# Out:
# Sonnet 99 is not 14 lines, skipping
# Sonnet 126 is not 14 lines, skipping

# %% [markdown]
# ## Visualization of the sparsities of A and O

# %%
visualize_sparsities(hmm, O_max_cols=200)

# %% [markdown]
# ## Generating a sample sentence

# %%
print('Sample Sentence:\n====================')
print(sample_sentence(hmm, hmm._word_dictionary, n_words=10))
# Out:
# Sample Sentence:
# ====================
# Expire child good this is the splendour consecrate expense rank...

# %%
for i in range(1):
    sonnet, sonnet_string = hmm.generate_sonnet()
    print(sonnet_string)
    print()
# Out:
# Acquaintance then calls then melancholy,
# Who morrow grief muse brings anticipate,
# My of in his her golden constancy,
# Of not not from i mayst of ruminate:
# Or love and my made mine unrespected,
# Dun have eye with tongue-tied unrespected,
# Our part there o'er-snowed live get directed,
# I of thee spend you engrossed directed:
# My records him fears me unrespected,
# In on hate new love eyes impanelled,
# Fading my or be face compare directed,
# Age powerful sweet blanks how determined:
#   And departest for to unrespected,
#   Mine base on love tend siren directed.

# %%
for i in range(1):
    sonnet, sonnet_string = hmm.generate_sonnet(rhyme=False)
    print(sonnet_string)
    print()
# Out:
# Work be after pain as their unfolding,
# To best some learn he for since as is love,
# I let self-example when fools doth the,
# Seem of of counting pain i those heart seen:
# Changing my own my fade sort will t' thee in,
# Breathe than cheeks are sins dark live shalt thou hell,
# Heart ah eyes y'have the account quite cheek of,
# The earthly yet nine meditation they:
# Dull knowledge may thou on this judgment love,
# Act with of brand me shines soul's style my will,
# Him my love wit alone rest thee glory,
# Thee not thee gulls to i mine thee beauty's:
#   Better my harmful alone and i'll of,
#   And confined that me friend habitation.

# %%
for i in range(1):
    haiku, haiku_string = hmm.generate_haiku()
    print(haiku_string)
    print()
# Out:
# Till shun in dead curse
# With argument the other
# Which nor making might

# %% [markdown]
# ## Visualizing the wordcloud of each state

# %%
wordclouds = states_to_wordclouds(hmm, hmm._word_dictionary, alt=True)

# %% [markdown]
# ## Visualizing the process of an HMM generating an emission

# %%
anim = animate_emission(hmm, hmm._word_dictionary, M=8, alt=True)
HTML(anim.to_html5_video())
# Out:
# Animating...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-7063b38de29b> in <module>()
#       1 anim = animate_emission(hmm, hmm._word_dictionary, M=8, alt=True)
# ----> 2 HTML(anim.to_html5_video())
#
# ~/miniconda3/lib/python3.6/site-packages/matplotlib/animation.py in to_html5_video(self, embed_limit)
#    1407                 # We create a writer manually so that we can get the
#    1408                 # appropriate size for the tag
# -> 1409                 Writer = writers[rcParams['animation.writer']]
#    1410                 writer = Writer(codec='h264',
#    1411                                 bitrate=rcParams['animation.bitrate'],
#
# ~/miniconda3/lib/python3.6/site-packages/matplotlib/animation.py in __getitem__(self, name)
#     168         if not self.avail:
#     169             raise RuntimeError("No MovieWriters available!")
# --> 170         return self.avail[name]
#     171
#     172 writers = MovieWriterRegistry()
#
# KeyError: 'ffmpeg'
